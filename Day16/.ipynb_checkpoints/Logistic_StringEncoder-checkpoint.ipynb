# %% [markdown]
# - Do the data cleaning and labeling if required-
# - Use Logistic Regression to Train Model
# - Predict the result spam/not

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("spam_dataset.csv")
df
# Out:
#                                        message_content  is_spam
# 0    Hello Lonnie,\n\nJust wanted to touch base reg...        0
# 1    Congratulations, you've won a prize! Call us n...        1
# 2    You have been pre-approved for a credit card w...        1
# 3    Limited time offer, act now! Only a few spots ...        1
# 4    Your loan has been approved! Transfer funds to...        1
# ..                                                 ...      ...
# 995  Hello Virginia,\n\nIt was great to catch up wi...        0
# 996  Final notice: Claim your inheritance from a di...        1
# 997  Hot singles in your area want to chat! Contact...        1
# 998  Your loan has been approved! Transfer funds to...        1
# 999  Dear Brian,\n\nI wanted to let you know about ...        0
#
# [1000 rows x 2 columns]

# %%
print('Number of Missing values are:\n',df.isnull().sum())
# Out:
# Number of Missing values are:
#  message_content    0
# is_spam            0
# dtype: int64

# %%
cv = CountVectorizer()
df['message_content'] = df['message_content'].astype(str)
vector_message = cv.fit_transform(df['message_content'])
x = vector_message 
y = df['is_spam']

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
new_msg = input("Enter your Email message:")
new_msg_vector = cv.fit_transform(['new_msg'])
predict_spam = model.predict(new_msg_vector)
if(predict_spam):
   print(f"The Message is SPAM")
else:
   print(f"The Message is not spam")
# Out:
# Enter your Email message: helo
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/st/_gypk6ws25q5h4zdnbgbsjw40000gn/T/ipykernel_3076/2625466971.py in ?()
#       1 new_msg = input("Enter your Email message:")
# ----> 2 predict_spam = model.predict(pd.DataFrame([[new_msg]], columns=['message_content']))
#       3 if(predict_spam):
#       4    print(f"The Message is SPAM")
#       5 else:
#
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py in ?(self, X)
#     370         y_pred : ndarray of shape (n_samples,)
#     371             Vector containing the class labels for each sample.
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#     377         else:
#
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_base.py in ?(self, X)
#     347         """
#     348         check_is_fitted(self)
#     349         xp, _ = get_namespace(X)
#     350
# --> 351         X = validate_data(self, X, accept_sparse="csr", reset=False)
#     352         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     353         return (
#     354             xp.reshape(scores, (-1,))
#
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'helo'
