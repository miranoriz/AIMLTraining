# %% [markdown]
# - Do the data cleaning and labeling if required-
# - Use Logistic Regression to Train Model
# - Predict the result spam/not

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv("spam_dataset.csv")
df
# Out:
#                                        message_content  is_spam
# 0    Hello Lonnie,\n\nJust wanted to touch base reg...        0
# 1    Congratulations, you've won a prize! Call us n...        1
# 2    You have been pre-approved for a credit card w...        1
# 3    Limited time offer, act now! Only a few spots ...        1
# 4    Your loan has been approved! Transfer funds to...        1
# ..                                                 ...      ...
# 995  Hello Virginia,\n\nIt was great to catch up wi...        0
# 996  Final notice: Claim your inheritance from a di...        1
# 997  Hot singles in your area want to chat! Contact...        1
# 998  Your loan has been approved! Transfer funds to...        1
# 999  Dear Brian,\n\nI wanted to let you know about ...        0
#
# [1000 rows x 2 columns]

# %%
print('Number of Missing values are:\n',df.isnull().sum())
# Out:
# Number of Missing values are:
#  message_content    0
# is_spam            0
# dtype: int64

# %%
cv = CountVectorizer()
x =cv.fit_transform(df['message_content'])
y = df['is_spam']

# %%
model = LogisticRegression()
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
new_msg = input("Enter your Email message: \n")
predict_spam = model.predict(cv.transform([new_msg]))

if(predict_spam):
   print(f"The Message is SPAM")
else:
   print(f"The Message is not spam")
# Out:
# Enter your Email message:
#  helo
# The Message is SPAM

# %%
xSpam = df['message_content']
ySpam = df['is_spam']
 
# Split the data (e.g., 80% for training, 20% for testing)
X_train_text, X_test_text, y_train, y_test = train_test_split(
    xSpam, 
    ySpam, 
    test_size=0.2, 
    random_state=42
)
print("Training samples:", len(X_train_text))
print("Testing samples:", len(X_test_text))
 
vectorizer = CountVectorizer()
X_train_numeric = vectorizer.fit_transform(X_train_text)
X_test_numeric = vectorizer.transform(X_test_text)
 
model_spam_email = LogisticRegression() 
model_spam_email.fit(X_train_numeric, y_train)
