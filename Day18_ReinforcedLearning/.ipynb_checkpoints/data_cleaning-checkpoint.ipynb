# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/aziim/Desktop/AIMLTraining/Day15_MachineLearning/student.csv")
df.head(5)
# Out:
#    Unnamed: 0    Id  Student_Age     Sex High_School_Type Scholarship  \
# 0           0  5001           21    Male            Other         50%
# 1           1  5002           20    Male            Other         50%
# 2           2  5003           21    Male            State         50%
# 3           3  5004           18  Female          Private         50%
# 4           4  5005           22    Male          Private         50%
#
#   Additional_Work Sports_activity Transportation  Weekly_Study_Hours  \
# 0             Yes              No        Private                   0
# 1             Yes              No        Private                   0
# 2              No              No        Private                   2
# 3             Yes              No            Bus                   2
# 4              No              No            Bus                  12
#
#   Attendance Reading Notes Listening_in_Class Project_work Grade
# ...

# %%
print('Number of Missing Values are:',df.isnull().sum())
# Out:
# Number of Missing Values are: Unnamed: 0            0
# Id                    0
# Student_Age           0
# Sex                   0
# High_School_Type      0
# Scholarship           1
# Additional_Work       0
# Sports_activity       0
# Transportation        0
# Weekly_Study_Hours    0
# Attendance            0
# Reading               0
# Notes                 0
# Listening_in_Class    0
# Project_work          0
# Grade                 0
# dtype: int64

# %%
df=pd.read_csv("/Users/aziim/Desktop/AIMLTraining/Day15_MachineLearning/students_performance_dirty.csv")
df.head(5)
# Out:
#    gender  study_hours  attendance_pct  math_score  reading_score  final_score
# 0    male          1.7            83.6        62.0           91.0         38.9
# 1     NaN          2.6            91.2        82.0           60.0         37.5
# 2  female          2.9            97.5        69.0           57.0         35.0
# 3  female          4.8            85.7        78.0           62.0         36.5
# 4    male          3.9           -10.0        64.0           95.0         30.9

# %%
rows_with_missing_data = df[df.isnull().any(axis=1)]
print("\nRows with missing data: \n")
print(rows_with_missing_data.to_string())
# Out:
# Rows with missing data:
#
#     gender  study_hours  attendance_pct  math_score  reading_score  final_score
# 1      NaN          2.6            91.2        82.0           60.0         37.5
# 6     male          NaN            87.1        95.0           78.0         43.4
# 7    femle          NaN            70.6        59.0           70.0         32.8
# 11     NaN          4.6            86.2        63.0           78.0         36.9
# 12   femle          NaN            95.0        59.0           92.0         39.7
# 13    male          NaN            86.5        61.0           50.0         30.8
# 20  female          NaN            93.5        65.0           54.0         33.1
# 28  female          NaN            71.7        65.0           53.0         30.8
# 33     NaN          NaN            96.0        39.0           96.0         36.6
# 34     NaN          3.6            91.3        64.0           62.0         34.2
# ...

# %%
num_rows = len(df)
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 60

# %%
count_missing_rows = df.isnull().any(axis=1).sum()
print("Total rows with at least one missing value:", count_missing_rows)
# Out:
# Total rows with at least one missing value: 15

# %%
count_rows_more_than_one_missing = (df.isnull().sum(axis=1) > 1).sum()
print("Total rows with more than one missing value:", count_rows_more_than_one_missing)
# Out:
# Total rows with more than one missing value: 1

# %%
print('Number of Missing Values are:',df.isnull().sum())
# Out:
# Number of Missing Values are: gender            8
# study_hours       8
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64

# %%
# to remove rows with undefined gender

df_drop_gender=df.dropna(subset="gender")
df_drop_gender
# Out:
#     gender  study_hours  attendance_pct  math_score  reading_score  \
# 0     male          1.7            83.6        62.0           91.0
# 2   female          2.9            97.5        69.0           57.0
# 3   female          4.8            85.7        78.0           62.0
# 4     male          3.9           -10.0        64.0           95.0
# 5     male          1.4            93.7        77.0           72.0
# 6     male          NaN            87.1        95.0           78.0
# 7    femle          NaN            70.6        59.0           70.0
# 8   female          2.7            74.7        68.0           71.0
# 9   female          4.2            92.4        63.0           66.0
# 10    male          4.7            67.9        94.0           73.0
# 12   femle          NaN            95.0        59.0           92.0
# 13    male          NaN            86.5        61.0           50.0
# 14    male          3.9            79.0        68.0           91.0
# ...

# %%
# to check again total number of rows after dropping unwanted rows

num_rows = len(df_drop_gender)
print(f"Number of rows: {num_rows}")
# Out:
# Number of rows: 52

# %%
import pandas as pd
df2 = df_drop_gender.copy()
df2.fillna(df_drop_gender['study_hours'].mean(), inplace=True)
df2
# Out:
#     gender  study_hours  attendance_pct  math_score  reading_score  \
# 0     male     1.700000            83.6        62.0           91.0
# 2   female     2.900000            97.5        69.0           57.0
# 3   female     4.800000            85.7        78.0           62.0
# 4     male     3.900000           -10.0        64.0           95.0
# 5     male     1.400000            93.7        77.0           72.0
# 6     male     3.393333            87.1        95.0           78.0
# 7    femle     3.393333            70.6        59.0           70.0
# 8   female     2.700000            74.7        68.0           71.0
# 9   female     4.200000            92.4        63.0           66.0
# 10    male     4.700000            67.9        94.0           73.0
# 12   femle     3.393333            95.0        59.0           92.0
# 13    male     3.393333            86.5        61.0           50.0
# 14    male     3.900000            79.0        68.0           91.0
# ...

# %%
#re-check total number of rows after dropping unwanted rows
#re-check for missing values in identified rows

num_rows = len(df_drop_gender)
print(f"Number of rows: {num_rows}")
print('Number of Missing Values are:',df.isnull().sum())
# Out:
# Number of rows: 52
# Number of Missing Values are: gender            8
# study_hours       8
# attendance_pct    0
# math_score        0
# reading_score     0
# final_score       0
# dtype: int64
